# %% [markdown]
# # Scenario 14 — Store Clustering Implementation
#
# Fit K-Means on standardised store KPIs, determine optimal k, profile clusters, and visualise with PCA. See `README.md` for full deliverables.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import joblib
from pathlib import Path
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

ARTIFACTS = Path('artifacts'); ARTIFACTS.mkdir(exist_ok=True)
FIGURES = Path('figures'); FIGURES.mkdir(exist_ok=True)

# %% [markdown]
# ## 1. Load scaled store KPIs from scenario 12 output

# %%
# TODO
# X = pd.read_parquet('../../data/processed/store_kpis_scaled.parquet')

# %% [markdown]
# ## 2. Elbow + silhouette for k = 2..10

# %%
# TODO
# inertias, silhouettes = [], []
# for k in range(2, 11):
#     km = KMeans(n_clusters=k, init='k-means++', n_init=10, random_state=42).fit(X)
#     inertias.append(km.inertia_)
#     silhouettes.append(silhouette_score(X, km.labels_))

# %% [markdown]
# ## 3. Fit final K-Means and persist

# %%
# TODO
# final_k = 5
# km = KMeans(n_clusters=final_k, init='k-means++', n_init=20, random_state=42).fit(X)
# joblib.dump(km, ARTIFACTS / 'kmeans_model.joblib')

# %% [markdown]
# ## 4. Cluster profiling — centroids in original scale + business names

# %%
# TODO: inverse_transform centroids, generate cluster_profiles.md content

# %% [markdown]
# ## 5. PCA visualisation

# %%
# TODO
# pca = PCA(n_components=2, random_state=42)
# X2 = pca.fit_transform(X)
# plt.scatter(X2[:, 0], X2[:, 1], c=km.labels_, alpha=0.5)
# plt.savefig(FIGURES / 'pca_clusters.png', dpi=150, bbox_inches='tight')
