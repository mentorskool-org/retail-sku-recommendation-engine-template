# %% [markdown]
# # Scenario 16 — Recommendation Optimization
#
# Build the rule-augmented recommendation engine. See `README.md` for deliverables and the rule precedence policy you'll define in `rules.md`.

# %%
import pandas as pd
import sys
sys.path.append('src')
# from recommend import select_top_skus, apply_business_rules

# %% [markdown]
# ## 1. Load clustering output + SKU performance

# %%
# TODO: load store→cluster map and sku profile from scenarios 12 and 14

# %% [markdown]
# ## 2. Generate baseline recommendations

# %%
# TODO: recs = select_top_skus(store_id, k=10)

# %% [markdown]
# ## 3. Layer business rules
#
# - mandatory SKUs
# - regional exclusions
# - target caps

# %%
# TODO: final = apply_business_rules(recs, store_meta)

# %% [markdown]
# ## 4. Edge cases: cap exceeded by mandatory, empty set, conflict resolution

# %%
# TODO: demonstrate each edge case with a small synthetic example
