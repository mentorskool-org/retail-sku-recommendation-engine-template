# %% [markdown]
# # Scenario 12 — Python Data Pipeline
#
# Build a reproducible Pandas pipeline that loads 5 raw sources, validates them, computes store KPIs, and profiles SKUs into L1–L4 tiers.
#
# Refer to `README.md` in this folder for the full set of objectives and deliverables.

# %% [markdown]
# ## 1. Setup

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.preprocessing import MinMaxScaler
import joblib

DATA_RAW = Path('../../data/raw')
DATA_PROCESSED = Path('../../data/processed')
ARTIFACTS = Path('artifacts')
ARTIFACTS.mkdir(exist_ok=True)

# %% [markdown]
# ## 2. Load and validate raw sources
#
# TODO: load the 5 CSVs and assert expected columns / row counts.

# %%
# TODO
# stores = pd.read_csv(DATA_RAW / 'stores.csv')
# products = pd.read_csv(DATA_RAW / 'products.csv')
# sales = pd.read_csv(DATA_RAW / 'sales.csv')
# targets = pd.read_csv(DATA_RAW / 'targets.csv')
# geo = pd.read_csv(DATA_RAW / 'geography.csv')

# %% [markdown]
# ## 3. Compute store KPIs with MinMaxScaler
#
# Persist the fitted scaler so new data can be scored consistently.

# %%
# TODO
# scaler = MinMaxScaler()
# store_kpis_scaled = scaler.fit_transform(store_kpis[['total_sales', 'total_units', 'distinct_skus']])
# joblib.dump(scaler, ARTIFACTS / 'scaler.joblib')

# %% [markdown]
# ## 4. SKU profiling — composite score + L1–L4 tiers

# %%
def profile_skus(sales_df: pd.DataFrame) -> pd.DataFrame:
    """Return SKU-level composite score and L1-L4 tier assignment.

    Composite combines price-to-units ratio, store presence, and sales rank.
    Tiers are quartiles of the composite (L1 = top quartile).
    """
    # TODO: implement
    raise NotImplementedError

# %% [markdown]
# ## 5. Validate tier distribution (~25% per quartile)

# %%
# TODO
# tier_counts = sku_profile['tier'].value_counts(normalize=True)
# assert (abs(tier_counts - 0.25) < 0.05).all(), tier_counts
